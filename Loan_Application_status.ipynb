# %% [markdown]
# ## Loan Status Prediction Project

# %% [markdown]
# ### Project Overview
#
#           This Project Predicts the loan status of a customer using Machine Learning. The model classifies whether a loan will be  **Approved or Not Approved** based on customer details.

# %% [markdown]
# ### Libraries Used

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Preprocessing steps

# %%
data=pd.read_csv(r"C:\Users\ELCOT\Downloads\loan_approval_dataset.csv")

# %%
data.head(5)
# Out:
#    loan_id  no_of_dependents      education  self_employed   income_annum  \
# 0        1                 2       Graduate             No        9600000
# 1        2                 0   Not Graduate            Yes        4100000
# 2        3                 3       Graduate             No        9100000
# 3        4                 3       Graduate             No        8200000
# 4        5                 5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1   no_of_dependents           4269 non-null   int64
#  2    education                 4269 non-null   str
#  3    self_employed             4269 non-null   str
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   str
# dtypes: int64(10), str(3)
# memory usage: 433.7 KB

# %% [markdown]
# ### Remove Unneccessary column

# %%
data.drop(columns=['loan_id'],inplace=True)

# %%
data.columns
# Out:
# Index(['no_of_dependents', ' education', ' self_employed', ' income_annum',
#        ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='str')

# %%
data.columns=data.columns.str.strip()

# %%
data.columns
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',
#        'loan_status'],
#       dtype='str')

# %%
data['Assets']=data.residential_assets_value+data.commercial_assets_value+data.luxury_assets_value+data.bank_asset_value

# %%
data.head(10)
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
# 5                 0       Graduate           Yes       4800000     13500000
# 6                 5       Graduate            No       8700000     33000000
# 7                 2       Graduate           Yes       5700000     15000000
# 8                 0       Graduate           Yes        800000      2200000
# 9                 5   Not Graduate            No       1100000      4300000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# ...

# %%
data.columns
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',
#        'loan_status', 'Assets'],
#       dtype='str')

# %%
data.drop(columns=['residential_assets_value','commercial_assets_value', 'luxury_assets_value', 'bank_asset_value'],inplace=True)

# %%
data.head(5)
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score loan_status    Assets
# 0         12          778    Approved  50700000
# 1          8          417    Rejected  17000000
# 2         20          506    Rejected  57700000
# 3          8          467    Rejected  52700000
# 4         20          382    Rejected  55000000

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   no_of_dependents  4269 non-null   int64
#  1   education         4269 non-null   str
#  2   self_employed     4269 non-null   str
#  3   income_annum      4269 non-null   int64
#  4   loan_amount       4269 non-null   int64
#  5   loan_term         4269 non-null   int64
#  6   cibil_score       4269 non-null   int64
#  7   loan_status       4269 non-null   str
#  8   Assets            4269 non-null   int64
# dtypes: int64(6), str(3)
# memory usage: 300.3 KB

# %%
data.isnull().sum()
# Out:
# no_of_dependents    0
# education           0
# self_employed       0
# income_annum        0
# loan_amount         0
# loan_term           0
# cibil_score         0
# loan_status         0
# Assets              0
# dtype: int64

# %%
data.head(5)
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score loan_status    Assets
# 0         12          778    Approved  50700000
# 1          8          417    Rejected  17000000
# 2         20          506    Rejected  57700000
# 3          8          467    Rejected  52700000
# 4         20          382    Rejected  55000000

# %%
data.loan_status.unique()
# Out:
# <StringArray>
# [' Approved', ' Rejected']
# Length: 2, dtype: str

# %% [markdown]
# ### Replacing all categorical column to numerical column

# %%
data['education']=data['education'].replace({' Graduate':1,' Not Graduate':0})
data['self_employed']=data['self_employed'].replace({' No':0,' Yes':1})
data['loan_status']=data['loan_status'].replace({' Approved':1,' Rejected':0})

# %%
data.head(5)
# Out:
#    no_of_dependents education self_employed  income_annum  loan_amount  \
# 0                 2         1             0       9600000     29900000
# 1                 0         0             1       4100000     12200000
# 2                 3         1             0       9100000     29700000
# 3                 3         1             0       8200000     30700000
# 4                 5         0             1       9800000     24200000
#
#    loan_term  cibil_score loan_status    Assets
# 0         12          778           1  50700000
# 1          8          417           0  17000000
# 2         20          506           0  57700000
# 3          8          467           0  52700000
# 4         20          382           0  55000000

# %%
from sklearn.model_selection import train_test_split

# %%
X=data.drop(columns=['loan_status']).astype(int)
y=data['loan_status'].astype(int)

# %%
X.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   no_of_dependents  4269 non-null   int64
#  1   education         4269 non-null   int64
#  2   self_employed     4269 non-null   int64
#  3   income_annum      4269 non-null   int64
#  4   loan_amount       4269 non-null   int64
#  5   loan_term         4269 non-null   int64
#  6   cibil_score       4269 non-null   int64
#  7   Assets            4269 non-null   int64
# dtypes: int64(8)
# memory usage: 266.9 KB

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4264    0
# 4265    1
# 4266    0
# 4267    1
# 4268    1
# Name: loan_status, Length: 4269, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=43)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((3415, 8), (854, 8), (3415,), (854,))

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(X_train)
x_test_scaled=scaler.fit_transform(X_test)

# %% [markdown]
# ## Machine Learning Models Used

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Model Evaluation

# %%
model.score(x_test_scaled,y_test)
# Out:
# 0.9297423887587822

# %%
pred_data=pd.DataFrame([['2','1','0','9600000','29900000','12','778','50700000']],columns=['no_of_dependents', 'education', 'self_employed', 'income_annum','loan_amount', 'loan_term', 'cibil_score','Assets'])

# %%
pred_data=scaler.transform(pred_data)

# %%
model.predict(pred_data)
# Out:
# array([1])

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# ### -> This model helps banks or financial institutions to decide whether a loan should be approved based on customer data.
# ### ->CIBIL Score: Highest impact; scores above 700 (e.g., 778 in approved samples) strongly favor approval, while low scores (e.g., 417) lead to rejection.
# ### ->Income & Assets: Annual income over 9M and total assets >50M correlate with approvals; low values signal risk.
# ### ->Dependents & Employment: More dependents or self-employment slightly hurt odds, but less than credit factors.

# %% [markdown]
# ##
